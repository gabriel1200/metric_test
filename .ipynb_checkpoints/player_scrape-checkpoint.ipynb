# %%
import pandas as pd
import time
import sys
def player_data(start_year,end_year,ps=False):
    if ps == False:
        season_type='leagues'
    else:
        season_type='playoffs'
    frames=[]
    for year in range(start_year,end_year+1):
        url = 'https://www.basketball-reference.com/'+season_type+'/NBA_'+str(year)+'_per_poss.html'
        df=pd.read_html(url)[0]
        df=df[df.Player!='Player']
        time.sleep(1)
        url2='https://www.basketball-reference.com/'+season_type+'/NBA_'+str(year)+'_advanced.html'
        df2=pd.read_html(url2)[0]
        df2=df2[df2.Player!='Player']

        

        year_df=df.merge(df2)
        unnamed=[col for col in year_df if 'unnamed' in col.lower()]
        year_df.drop(columns=unnamed,inplace=True)
        year_df['year']=year
        frames.append(year_df)
        print(year)

        time.sleep(2)
    return pd.concat(frames)
start_year=1974
end_year=2024
#player_stats=player_data(start_year,end_year)

#player_stats.to_csv('player_stats.csv',index=False)
#player_stats_ps=player_data(start_year,end_year,ps=True)
#player_stats_ps.to_csv('player_stats_ps.csv',index=False)

# %%
def league_average(league='leagues'):
    time.sleep(1)
    league_url='https://www.basketball-reference.com/'+league+'/NBA_stats_per_poss.html'
    frames=pd.read_html(league_url)
    league = frames[0]
    league.columns=league.columns.droplevel()
    league=league[league.Season!='Season']

    league2 = frames[1]
    league2.columns=league2.columns.droplevel()
    league2=league2[league2.Season!='Season']
    
    
    return league,league2
league,league2 = league_average()
league.to_csv('league_average.csv',index=False)

league2.to_csv('league_average_ps.csv',index=False)

# %%
league2
# Out:
#     Rk   Season   Lg   Age   Ht   Wt   G    FG   FGA    3P  ...   FG%   3P%  \
# 0    1  2023-24  NBA  26.4  6-7  216  82  41.9  90.7  12.6  ...  .462  .351
# 1    2  2022-23  NBA  26.1  6-6  216  84  41.6  90.3  12.5  ...  .461  .351
# 2    3  2021-22  NBA  26.1  6-6  215  87  39.9  87.6  12.8  ...  .456  .355
# 3    4  2020-21  NBA  26.1  6-6  217  85  41.6  90.0  12.9  ...  .462  .364
# 4    5  2019-20  NBA  26.1  6-6  218  83  39.4  86.3  13.3  ...  .457  .360
# ..  ..      ...  ...   ...  ...  ...  ..   ...   ...   ...  ...   ...   ...
# 79  74  1950-51  NBA   NaN  NaN  NaN  26   NaN   NaN   NaN  ...  .376   NaN
# 80  75  1949-50  NBA   NaN  NaN  NaN  30   NaN   NaN   NaN  ...  .344   NaN
# 81  76  1948-49  BAA   NaN  NaN  NaN  20   NaN   NaN   NaN  ...  .329   NaN
# 82  77  1947-48  BAA   NaN  NaN  NaN  21   NaN   NaN   NaN  ...  .272   NaN
# 83  78  1946-47  BAA   NaN  NaN  NaN  19   NaN   NaN   NaN  ...  .265   NaN
#
#      FT%  Pace  eFG%  TOV%  ORB% FT/FGA   ORtg   TS%
# 0   .779  92.7  .532  11.6  24.1   .188  113.5  .566
# 1   .794  96.1  .530  11.7  24.0   .197  113.5  .566
# 2   .785  95.5  .529  12.8  22.3   .212  111.2  .567
# 3   .786  96.1  .534  11.2  22.8   .201  114.3  .571
# 4   .788  97.6  .534  12.8  20.4   .221  111.3  .574
# ..   ...   ...   ...   ...   ...    ...    ...   ...
# 79  .723   NaN  .376   NaN   NaN   .308    NaN  .446
# 80  .732   NaN  .344   NaN   NaN   .343    NaN  .427
# 81  .717   NaN  .329   NaN   NaN   .306    NaN  .405
# 82  .701   NaN  .272   NaN   NaN   .244    NaN  .342
# 83  .686   NaN  .265   NaN   NaN   .182    NaN  .319
#
# [81 rows x 32 columns]

# %%
players = pd.read_csv('player_stats.csv')
players.rename(columns={'Player':'player'},inplace=True)
player_index=pd.read_csv('index_master.csv')
players=players.merge(player_index,on=['player','year'])

players.to_csv('player_stats.csv',index=False)
players
# Out:
#         Rk             player Pos  Age   Tm   G  GS    MP    FG   FGA  ...  \
# 0        1  Tariq Abdul-Wahad  SG   25  TOT  61  56  1578   8.6  20.3  ...
# 1        1  Tariq Abdul-Wahad  SG   25  TOT  61  56  1578   8.6  20.3  ...
# 2        1  Tariq Abdul-Wahad  SG   25  TOT  61  56  1578   8.6  20.3  ...
# 3        1  Tariq Abdul-Wahad  SG   25  ORL  46  46  1205   9.1  21.1  ...
# 4        1  Tariq Abdul-Wahad  SG   25  ORL  46  46  1205   9.1  21.1  ...
# ...    ...                ...  ..  ...  ...  ..  ..   ...   ...   ...  ...
# 22754  568     Thaddeus Young  PF   35  PHO  10   0    89   6.0  11.5  ...
# 22755  569         Trae Young  PG   25  ATL  54  54  1942  10.7  24.9  ...
# 22756  570     Omer Yurtseven   C   25  UTA  48  12   545   8.8  16.3  ...
# 22757  571        Cody Zeller   C   31  NOP  43   0   320   4.0   9.5  ...
# 22758  572        Ivica Zubac   C   26  LAC  68  68  1794   9.3  14.3  ...
#
#         WS  WS/48  OBPM  DBPM  BPM  VORP  year  \
# 0      2.2  0.068  -1.2  -0.1 -1.2   0.3  2000
# 1      2.2  0.068  -1.2  -0.1 -1.2   0.3  2000
# 2      2.2  0.068  -1.2  -0.1 -1.2   0.3  2000
# 3      2.0  0.082  -1.0   0.2 -0.8   0.4  2000
# 4      2.0  0.082  -1.0   0.2 -0.8   0.4  2000
# ...    ...    ...   ...   ...  ...   ...   ...
# 22754  0.3  0.137  -1.5   0.6 -0.9   0.0  2024
# 22755  4.6  0.114   4.9  -2.3  2.6   2.2  2024
# 22756  0.7  0.062  -1.6  -1.5 -3.0  -0.1  2024
# 22757  0.8  0.124  -2.9   0.3 -2.6   0.0  2024
# 22758  6.8  0.182   0.8   0.0  0.8   1.3  2024
#
#                                                      url    bref_id     nba_id
# 0      https://www.basketball-reference.com/players/a...  abdulta01     1505.0
# 1      https://www.basketball-reference.com/players/a...  abdulta01     1505.0
# 2      https://www.basketball-reference.com/players/a...  abdulta01     1505.0
# 3      https://www.basketball-reference.com/players/a...  abdulta01     1505.0
# 4      https://www.basketball-reference.com/players/a...  abdulta01     1505.0
# ...                                                  ...        ...        ...
# 22754  https://www.basketball-reference.com/players/y...  youngth01   201152.0
# 22755  https://www.basketball-reference.com/players/y...  youngtr01  1629027.0
# 22756  https://www.basketball-reference.com/players/y...  yurtsom01  1630209.0
# 22757  https://www.basketball-reference.com/players/z...  zelleco01   203469.0
# 22758  https://www.basketball-reference.com/players/z...  zubaciv01  1627826.0
#
# [22759 rows x 55 columns]

# %%
players = pd.read_csv('player_stats_ps.csv')
players.rename(columns={'Player':'player'},inplace=True)
player_index=pd.read_csv('index_master.csv')
players=players.merge(player_index,on=['player','year'])

players.to_csv('player_stats_ps.csv',index=False)
players
# Out:
#        Rk          player Pos  Age   Tm   G  GS   MP    FG   FGA  ...   WS  \
# 0       2    Rafer Alston  PG   23  MIL   4   0   16   0.0  10.1  ... -0.1
# 1       3   Nick Anderson  SG   32  SAC   5   5  132   4.4  13.5  ...  0.0
# 2       4    Greg Anthony  PG   32  POR  15   0  213   5.0  13.6  ...  0.4
# 3       5   Stacey Augmon  SG   31  POR   7   0   34   6.6  19.7  ... -0.1
# 4       6     Toby Bailey  SG   24  PHO   5   0   15   3.5  14.2  ...  0.0
# ...   ...             ...  ..  ...  ...  ..  ..  ...   ...   ...  ...  ...
# 5536  212    Delon Wright  PG   31  MIA   4   1  107   5.9   9.9  ...  0.4
# 5537  213  Thaddeus Young  PF   35  PHO   1   0    4   0.0   0.0  ...  0.0
# 5538  213  Thaddeus Young  PF   35  PHO   1   0    4   0.0   0.0  ...  0.0
# 5539  213  Thaddeus Young  PF   35  PHO   1   0    4   0.0   0.0  ...  0.0
# 5540  214     Ivica Zubac   C   26  LAC   6   6  192  11.5  19.2  ...  0.6
#
#       WS/48  OBPM  DBPM   BPM  VORP  year  \
# 0    -0.367 -11.3  -6.9 -18.3  -0.1  2000
# 1    -0.014  -1.1  -1.3  -2.4   0.0  2000
# 2     0.095  -0.5   3.2   2.7   0.3  2000
# 3    -0.071  -8.0  -3.7 -11.7  -0.1  2000
# 4     0.036   0.6  -0.6   0.0   0.0  2000
# ...     ...   ...   ...   ...   ...   ...
# 5536  0.158   0.1   3.8   3.9   0.2  2024
# 5537 -0.073  -3.2  -3.1  -6.3   0.0  2024
# 5538 -0.073  -3.2  -3.1  -6.3   0.0  2024
# 5539 -0.073  -3.2  -3.1  -6.3   0.0  2024
# 5540  0.141   1.2   0.3   1.4   0.2  2024
#
#                                                     url    bref_id     nba_id
# 0     https://www.basketball-reference.com/players/a...  alstora01     1747.0
# 1     https://www.basketball-reference.com/players/a...  anderni01       98.0
# 2     https://www.basketball-reference.com/players/a...  anthogr01       21.0
# 3     https://www.basketball-reference.com/players/a...  augmost01      278.0
# 4     https://www.basketball-reference.com/players/b...  baileto01     1753.0
# ...                                                 ...        ...        ...
# 5536  https://www.basketball-reference.com/players/w...  wrighde01  1626153.0
# 5537  https://www.basketball-reference.com/players/y...  youngth01   201152.0
# 5538  https://www.basketball-reference.com/players/y...  youngth01   201152.0
# 5539  https://www.basketball-reference.com/players/y...  youngth01   201152.0
# 5540  https://www.basketball-reference.com/players/z...  zubaciv01  1627826.0
#
# [5541 rows x 55 columns]

# %%
players.dropna(subset='nba_id')
# Out:
#         Rk             player Pos  Age   Tm   G  GS    MP    FG   FGA  ...  \
# 0        1  Tariq Abdul-Wahad  SG   25  TOT  61  56  1578   8.6  20.3  ...
# 1        1  Tariq Abdul-Wahad  SG   25  TOT  61  56  1578   8.6  20.3  ...
# 2        1  Tariq Abdul-Wahad  SG   25  TOT  61  56  1578   8.6  20.3  ...
# 3        1  Tariq Abdul-Wahad  SG   25  ORL  46  46  1205   9.1  21.1  ...
# 4        1  Tariq Abdul-Wahad  SG   25  ORL  46  46  1205   9.1  21.1  ...
# ...    ...                ...  ..  ...  ...  ..  ..   ...   ...   ...  ...
# 22754  568     Thaddeus Young  PF   35  PHO  10   0    89   6.0  11.5  ...
# 22755  569         Trae Young  PG   25  ATL  54  54  1942  10.7  24.9  ...
# 22756  570     Omer Yurtseven   C   25  UTA  48  12   545   8.8  16.3  ...
# 22757  571        Cody Zeller   C   31  NOP  43   0   320   4.0   9.5  ...
# 22758  572        Ivica Zubac   C   26  LAC  68  68  1794   9.3  14.3  ...
#
#         WS  WS/48  OBPM  DBPM  BPM  VORP  year  \
# 0      2.2  0.068  -1.2  -0.1 -1.2   0.3  2000
# 1      2.2  0.068  -1.2  -0.1 -1.2   0.3  2000
# 2      2.2  0.068  -1.2  -0.1 -1.2   0.3  2000
# 3      2.0  0.082  -1.0   0.2 -0.8   0.4  2000
# 4      2.0  0.082  -1.0   0.2 -0.8   0.4  2000
# ...    ...    ...   ...   ...  ...   ...   ...
# 22754  0.3  0.137  -1.5   0.6 -0.9   0.0  2024
# 22755  4.6  0.114   4.9  -2.3  2.6   2.2  2024
# 22756  0.7  0.062  -1.6  -1.5 -3.0  -0.1  2024
# 22757  0.8  0.124  -2.9   0.3 -2.6   0.0  2024
# 22758  6.8  0.182   0.8   0.0  0.8   1.3  2024
#
#                                                      url    bref_id     nba_id
# 0      https://www.basketball-reference.com/players/a...  abdulta01     1505.0
# 1      https://www.basketball-reference.com/players/a...  abdulta01     1505.0
# 2      https://www.basketball-reference.com/players/a...  abdulta01     1505.0
# 3      https://www.basketball-reference.com/players/a...  abdulta01     1505.0
# 4      https://www.basketball-reference.com/players/a...  abdulta01     1505.0
# ...                                                  ...        ...        ...
# 22754  https://www.basketball-reference.com/players/y...  youngth01   201152.0
# 22755  https://www.basketball-reference.com/players/y...  youngtr01  1629027.0
# 22756  https://www.basketball-reference.com/players/y...  yurtsom01  1630209.0
# 22757  https://www.basketball-reference.com/players/z...  zelleco01   203469.0
# 22758  https://www.basketball-reference.com/players/z...  zubaciv01  1627826.0
#
# [22759 rows x 55 columns]
